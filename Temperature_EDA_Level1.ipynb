# %% [markdown]
# **Level 1 - UNDERSTANDING THE DATA**

# %% [markdown]
# Data Loading & Inspection

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('/content/Manteca2023.xlsx')

# %%
df.info() #to check column types and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              365 non-null    datetime64[ns]
#  1   max_temp_f        365 non-null    int64
#  2   avg_temp_f        365 non-null    float64
#  3   min_temp_f        365 non-null    int64
#  4   max_dew_point_f   365 non-null    int64
#  5   avg_dew_point_f   365 non-null    float64
#  6   min_dew_point_f   365 non-null    int64
#  7   max_humidity_pct  365 non-null    int64
#  8   avg_humidity_pct  365 non-null    float64
#  9   min_humidity_pct  365 non-null    int64
#  10  max_wind_mph      365 non-null    int64
#  11  avg_wind_mph      365 non-null    float64
#  12  min_wind_mph      365 non-null    int64
#  13  max_pressure_in   365 non-null    float64
#  14  avg_pressure_in   365 non-null    float64
#  15  min_pressure_in   365 non-null    float64
#  16  precip_in         365 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(8)
# memory usage: 48.6 KB

# %%
df.describe() #to check summary statistics
# Out:
#                       date  max_temp_f  avg_temp_f  min_temp_f  \
# count                  365  365.000000   365.00000  365.000000
# mean   2023-07-02 00:00:00   75.232877    61.64411   49.589041
# min    2023-01-01 00:00:00   47.000000    39.60000    0.000000
# 25%    2023-04-02 00:00:00   62.000000    50.80000   41.000000
# 50%    2023-07-02 00:00:00   74.000000    61.00000   51.000000
# 75%    2023-10-01 00:00:00   88.000000    71.20000   58.000000
# max    2023-12-31 00:00:00  108.000000    89.40000   73.000000
# std                    NaN   15.056779    12.36459   10.747649
#
#        max_dew_point_f  avg_dew_point_f  min_dew_point_f  max_humidity_pct  \
# count       365.000000       365.000000       365.000000        365.000000
# mean         50.906849        46.801370        41.953425         85.687671
# min          28.000000        23.300000         0.000000         55.000000
# 25%          46.000000        40.900000        35.000000         80.000000
# 50%          52.000000        48.700000        43.000000         87.000000
# 75%          57.000000        53.000000        49.000000         93.000000
# max          67.000000        63.100000        59.000000        100.000000
# std           7.553988         7.891658         9.056934          9.498756
#
#        avg_humidity_pct  min_humidity_pct  max_wind_mph  avg_wind_mph  \
# count        365.000000        365.000000    365.000000    365.000000
# mean          63.054247         37.969863     14.246575      7.250411
# min           27.700000          0.000000      5.000000      1.100000
# 25%           53.300000         27.000000     10.000000      4.800000
# 50%           60.600000         35.000000     14.000000      7.000000
# 75%           73.500000         46.000000     16.000000      8.800000
# max           95.300000         93.000000     38.000000     19.600000
# std           14.303355         15.683044      6.083171      3.436749
#
#        min_wind_mph  max_pressure_in  avg_pressure_in  min_pressure_in  \
# count    365.000000       365.000000       365.000000       365.000000
# mean       1.186301        30.006301        29.938082        29.877534
# min        0.000000        29.700000        29.400000        29.300000
# 25%        0.000000        29.900000        29.800000        29.800000
# 50%        0.000000        30.000000        29.900000        29.900000
# 75%        0.000000        30.100000        30.000000        30.000000
# max       10.000000        30.400000        30.400000        30.300000
# std        2.308210         0.151689         0.151555         0.159806
#
#         precip_in
# count  365.000000
# mean     0.053644
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      2.710000
# std      0.218553

# %%
df.head() #to check first few rows
# Out:
#         date  max_temp_f  avg_temp_f  min_temp_f  max_dew_point_f  \
# 0 2023-01-01          60        52.1          42               45
# 1 2023-01-02          49        44.1          38               43
# 2 2023-01-03          49        45.9          42               45
# 3 2023-01-04          62        51.1          42               51
# 4 2023-01-05          58        53.5          49               52
#
#    avg_dew_point_f  min_dew_point_f  max_humidity_pct  avg_humidity_pct  \
# 0             37.8               35                79              59.5
# 1             39.1               34                93              83.3
# 2             43.5               41                97              91.8
# 3             45.8               41                97              83.5
# 4             49.1               46                93              85.1
#
#    min_humidity_pct  max_wind_mph  avg_wind_mph  min_wind_mph  \
# 0                42            23          15.5             8
# 1                69            17           9.5             0
# 2                86             8           3.1             0
# 3                56            37          14.7             0
# 4                75            29          14.8             6
#
#    max_pressure_in  avg_pressure_in  min_pressure_in  precip_in
# 0             29.9             29.8             29.6       2.71
# 1             29.9             29.9             29.8       0.00
# 2             30.0             30.0             29.9       0.57
# 3             30.0             29.8             29.6       0.00
# 4             30.2             29.9             29.7       0.42

# %%
df.tail() #to check last few rows
# Out:
#           date  max_temp_f  avg_temp_f  min_temp_f  max_dew_point_f  \
# 360 2023-12-27          64        48.3          39               52
# 361 2023-12-28          66        55.8          51               53
# 362 2023-12-29          67        57.4          51               54
# 363 2023-12-30          61        53.9          50               53
# 364 2023-12-31          58        52.2          48               51
#
#      avg_dew_point_f  min_dew_point_f  max_humidity_pct  avg_humidity_pct  \
# 360             46.0               39               100              92.5
# 361             50.8               49                97              84.3
# 362             50.4               47                97              79.1
# 363             51.2               49               100              90.8
# 364             49.3               47               100              90.5
#
#      min_humidity_pct  max_wind_mph  avg_wind_mph  min_wind_mph  \
# 360                54            15           5.6             0
# 361                59            10           5.1             0
# 362                54            17           8.5             0
# 363                67             8           3.7             0
# 364                75             9           3.4             0
#
#      max_pressure_in  avg_pressure_in  min_pressure_in  precip_in
# 360             30.1             30.1             30.0       0.00
# 361             30.2             30.1             30.0       0.17
# 362             30.0             29.9             29.9       0.00
# 363             30.1             30.0             30.0       0.99
# 364             30.1             30.1             30.0       0.02

# %% [markdown]
# Date Range & Completeness

# %%
#using .min() and .max() to check the range of date
df['date'].min()
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
df['date'].max()
# Out:
# Timestamp('2023-12-31 00:00:00')

# %%
#counting unique dates
df['date'].nunique()
# Out:
# 365

# %%
#checking duplicate dates
df['date'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Daily Visualizations

# %%
#daily average temperature using matplotlib
import matplotlib.pyplot as plt

plt.plot(df['date'],df['avg_temp_f'])
plt.xlabel('Date')
plt.ylabel('Average Temperature')
plt.title('Daily Temperature')
plt.show()

# %%
#matplotlib daily humidity
plt.plot(df['date'],df['avg_humidity_pct'])
plt.xlabel('Date')
plt.ylabel('Average Humidity')
plt.title('Daily Humidity')
plt.show()

# %%
#plotting daily precipitation
plt.plot(df['date'],df['precip_in'])
plt.xlabel('Date')
plt.ylabel('Average Precipitation')
plt.title('Daily Precipitation')
plt.show()

# %% [markdown]
# Monthly Aggregates & Plots

# %%
#convert date colunm using datetime()
df['date'] = pd.to_datetime(df['date'])
df['date'].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 360    12
# 361    12
# 362    12
# 363    12
# 364    12
# Name: date, Length: 365, dtype: int32

# %%
#creating new colunms
df['month'] = df['date'].dt.month
df['month_name'] = df['date'].dt.strftime('%b')

# %%
#calculating monthly averages
import calendar
monthly_avg = df.groupby('month').agg({
    'avg_temp_f': 'mean',
    'avg_humidity_pct': 'mean',
    'avg_dew_point_f': 'mean',
    'avg_wind_mph': 'mean',
    'avg_pressure_in': 'mean'
}).reset_index()

#readability
monthly_avg['month_name'] = monthly_avg['month'].apply(lambda x: calendar.month_abbr[x])

#Reorder columns for clarity
monthly_avg = monthly_avg[['month', 'month_name', 'avg_temp_f', 'avg_humidity_pct',
                           'avg_dew_point_f', 'avg_wind_mph', 'avg_pressure_in']]

#Round values for readability
monthly_avg = monthly_avg.round(2)

# Sort by month
monthly_avg = monthly_avg.sort_values('month')

# Display
monthly_avg
# Out:
#     month month_name  avg_temp_f  avg_humidity_pct  avg_dew_point_f  \
# 0       1        Jan       48.77             77.01            41.16
# 1       2        Feb       46.77             71.59            36.79
# 2       3        Mar       51.13             72.90            41.86
# 3       4        Apr       59.57             59.33            43.76
# 4       5        May       64.74             62.05            49.91
# 5       6        Jun       69.79             54.76            51.06
# 6       7        Jul       79.52             43.48            52.52
# 7       8        Aug       78.76             50.31            56.73
# 8       9        Sep       70.77             58.08            53.57
# 9      10        Oct       65.33             57.75            48.04
# 10     11        Nov       53.95             66.26            41.29
# 11     12        Dec       49.45             83.51            44.05
#
#     avg_wind_mph  avg_pressure_in
# 0           9.42            29.99
# 1           7.74            30.03
# 2           9.09            29.95
# 3           8.39            30.00
# 4           8.06            29.88
# 5           8.54            29.86
# 6           7.63            29.84
# 7           7.25            29.84
# 8           7.02            29.88
# 9           5.27            29.90
# 10          4.18            30.03
# 11          4.43            30.06

# %%
df.head()
# Out:
#         date  max_temp_f  avg_temp_f  min_temp_f  max_dew_point_f  \
# 0 2023-01-01          60        52.1          42               45
# 1 2023-01-02          49        44.1          38               43
# 2 2023-01-03          49        45.9          42               45
# 3 2023-01-04          62        51.1          42               51
# 4 2023-01-05          58        53.5          49               52
#
#    avg_dew_point_f  min_dew_point_f  max_humidity_pct  avg_humidity_pct  \
# 0             37.8               35                79              59.5
# 1             39.1               34                93              83.3
# 2             43.5               41                97              91.8
# 3             45.8               41                97              83.5
# 4             49.1               46                93              85.1
#
#    min_humidity_pct  max_wind_mph  avg_wind_mph  min_wind_mph  \
# 0                42            23          15.5             8
# 1                69            17           9.5             0
# 2                86             8           3.1             0
# 3                56            37          14.7             0
# 4                75            29          14.8             6
#
#    max_pressure_in  avg_pressure_in  min_pressure_in  precip_in  month  \
# 0             29.9             29.8             29.6       2.71      1
# 1             29.9             29.9             29.8       0.00      1
# 2             30.0             30.0             29.9       0.57      1
# 3             30.0             29.8             29.6       0.00      1
# 4             30.2             29.9             29.7       0.42      1
#
#   month_name
# 0        Jan
# 1        Jan
# 2        Jan
# 3        Jan
# 4        Jan

# %% [markdown]
# Observations & Insight

# %%
#Box plots for temperature spread per month using seaborn
import seaborn as sns
sns.boxplot(data=df, x='month_name', y='avg_temp_f')
plt.show()

# %%
#Box plots for humidity per month using seaborn
sns.boxplot(data=df, x='month_name', y='avg_humidity_pct')
plt.show()

# %%
#Box plots for dew point per month using seaborn
sns.boxplot(data=df, x='month_name', y='avg_dew_point_f')
plt.show()

# %%
#Box plots for precipitation per month using seaborn
sns.boxplot(data=df, x='month_name', y='precip_in')
plt.show()

# %%
#Box plots for wind speeds per month using seaborn
sns.boxplot(data=df, x='month_name', y='avg_wind_mph')
plt.show()

# %%
#Box plots for pressure per month using seaborn
sns.boxplot(data=df, x='month_name', y='avg_pressure_in')
plt.show()

# %% [markdown]
# **Data Quality - Missingness and outliers**

# %%
#find missing data
df.isnull().sum()
# Out:
# date                0
# max_temp_f          0
# avg_temp_f          0
# min_temp_f          0
# max_dew_point_f     0
# avg_dew_point_f     0
# min_dew_point_f     0
# max_humidity_pct    0
# avg_humidity_pct    0
# min_humidity_pct    0
# max_wind_mph        0
# avg_wind_mph        0
# min_wind_mph        0
# max_pressure_in     0
# avg_pressure_in     0
# min_pressure_in     0
# precip_in           0
# month               0
# month_name          0
# dtype: int64

# %%
#missingno library : to visualize and
#understand missing data patterns within datasets,
#particularly those structured as Pandas DataFrames.
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >
